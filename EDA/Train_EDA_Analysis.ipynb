# %% [markdown]
# ## EDA Analysis

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('train.csv')
data.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
missing_col = data.isnull().sum()/len(data.index) * 100
missing_col[missing_col > 50]
# Out:
# Alley          93.767123
# PoolQC         99.520548
# Fence          80.753425
# MiscFeature    96.301370
# dtype: float64

# %%
def missing(missing_perc):
   missing = data.isnull().sum()/len(data.index) * 100
   return missing[missing >= missing_perc]

missing(50)
# Out:
# Alley          93.767123
# PoolQC         99.520548
# Fence          80.753425
# MiscFeature    96.301370
# dtype: float64

# %% [markdown]
# ## Drop these columns, its no more useful

# %%
drop_col = ['Alley', 'PoolQC', 'Fence', 'MiscFeature']
data.drop(columns=drop_col, axis=1, inplace=True)

# %%
missing(10)
# Out:
# LotFrontage    17.739726
# FireplaceQu    47.260274
# dtype: float64

# %%
data.shape
# Out:
# (1460, 77)

# %%
data.dtypes.value_counts()
# Out:
# object     39
# int64      35
# float64     3
# dtype: int64

# %%
data.select_dtypes(include = object).describe()
# Out:
#        MSZoning Street LotShape  ... PavedDrive SaleType SaleCondition
# count      1460   1460     1460  ...       1460     1460          1460
# unique        5      2        4  ...          3        9             6
# top          RL   Pave      Reg  ...          Y       WD        Normal
# freq       1151   1454      925  ...       1340     1267          1198
#
# [4 rows x 39 columns]

# %%
data.select_dtypes(include='int64').describe()
# Out:
#                 Id   MSSubClass  ...       YrSold      SalePrice
# count  1460.000000  1460.000000  ...  1460.000000    1460.000000
# mean    730.500000    56.897260  ...  2007.815753  180921.195890
# std     421.610009    42.300571  ...     1.328095   79442.502883
# min       1.000000    20.000000  ...  2006.000000   34900.000000
# 25%     365.750000    20.000000  ...  2007.000000  129975.000000
# 50%     730.500000    50.000000  ...  2008.000000  163000.000000
# 75%    1095.250000    70.000000  ...  2009.000000  214000.000000
# max    1460.000000   190.000000  ...  2010.000000  755000.000000
#
# [8 rows x 35 columns]

# %%
data.select_dtypes(include='float').describe()
# Out:
#        LotFrontage   MasVnrArea  GarageYrBlt
# count  1201.000000  1452.000000  1379.000000
# mean     70.049958   103.685262  1978.506164
# std      24.284752   181.066207    24.689725
# min      21.000000     0.000000  1900.000000
# 25%      59.000000     0.000000  1961.000000
# 50%      69.000000     0.000000  1980.000000
# 75%      80.000000   166.000000  2002.000000
# max     313.000000  1600.000000  2010.000000

# %%
#Let's visualize SalesPrice
data['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(9,7))

sns.distplot(data['SalePrice'], color='g', bins=200, hist_kws={'alpha' : 0.4})
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
sns.distplot(data['SalePrice'])

# %%
sns.distplot(data['SalePrice'], rug=True, hist=False)

# %%
from scipy.stats import norm
ax = sns.distplot(data['SalePrice'], fit=norm, kde=False)

# %%
sns.distplot(data['SalePrice'], vertical=True)

# %%
sns.distplot(data['SalePrice'], rug=True, rug_kws={"color": "g"},
                  kde_kws={"color": "k", "lw": 3, "label": "SalePrice"},
                  hist_kws={"histtype": "step", "linewidth": 3,
                            "alpha": 1, "color": "g"})

# %%
# To select num data type:
df_num = data.select_dtypes(include = ['float64', 'int64'])
df_num.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  ...  MiscVal  MoSold  YrSold  SalePrice
# 0   1          60         65.0     8450  ...        0       2    2008     208500
# 1   2          20         80.0     9600  ...        0       5    2007     181500
# 2   3          60         68.0    11250  ...        0       9    2008     223500
# 3   4          70         60.0     9550  ...        0       2    2006     140000
# 4   5          60         84.0    14260  ...        0      12    2008     250000
#
# [5 rows x 38 columns]

# %%
df_num.describe(include='all')
# Out:
#                 Id   MSSubClass  ...       YrSold      SalePrice
# count  1460.000000  1460.000000  ...  1460.000000    1460.000000
# mean    730.500000    56.897260  ...  2007.815753  180921.195890
# std     421.610009    42.300571  ...     1.328095   79442.502883
# min       1.000000    20.000000  ...  2006.000000   34900.000000
# 25%     365.750000    20.000000  ...  2007.000000  129975.000000
# 50%     730.500000    50.000000  ...  2008.000000  163000.000000
# 75%    1095.250000    70.000000  ...  2009.000000  214000.000000
# max    1460.000000   190.000000  ...  2010.000000  755000.000000
#
# [8 rows x 38 columns]
